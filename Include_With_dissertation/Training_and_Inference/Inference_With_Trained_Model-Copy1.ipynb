# %%
# Simulate a webcam using a video file and display the video with inference results in real time.
# OpenCV and a pre-trained YOLO model to process each frame of the video and display the results.

# Read a video frame by frame.
# Run YOLO Inference process each frame with the YOLO model.
# Display the results in real-time render the video output with bounding boxes and class labels.
import cv2
from ultralytics import YOLO
# Path to the video file
# OpenCV's cv2.VideoCapture doesn't support streaming video directly from YouTube URLs. 
# It only works with local video files or camera streams.
#video_path="C:/Users/peter/projects/classifyflagbs/Include_With_dissertation/Training_and_Inference/Flags3Compilation.mp4" # Video 2
#video_path='D:/Brid_Videos/July29/WhiteStrand/29072024_Red_Yellow_Flag_2.mp4'
#video_path = 'D:/Brid_Videos/Home_Videos/Red_yellow_flag_moderate_wind_2.mp4'  
#output_path = 'D:/FlagDetectionDatasets/A_Videos_Inference_Output/DetectionOf_Flag3.mp4'  
video_path='D:/Brid_Videos/July29/WhiteStrand/29072024_RedYellowFlag3.mp4'
# Load the YOLO model
model = YOLO("Set_1_Selected_TestC_BEST.pt")  # Trained modelQ 1 
#model = YOLO("best_Data1_Test2.pt")  # Trained modelQ 1 
#model = YOLO("best.pt")  # Trained modelQ 1 
#model = YOLO("best_Model2.pt")  # Traeined model 1 

# Open the video file
cap = cv2.VideoCapture(video_path)

if not cap.isOpened():
    print("Error: Cannot open video file.")
    exit()

# Simulate a webcam by reading frames
while True:
    ret, frame = cap.read()
    if not ret:
        print("End of video or cannot read frame.")
        break

    # Run YOLO inference on the frame
    results = model.predict(frame, conf=0.5)  # Set confidence threshold

    # Annotate the frame with YOLO predictions
    annotated_frame = results[0].plot()

    # Display the annotated frame
    cv2.imshow("Video Inference", annotated_frame)

    #Press 'q' to quit the video
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

    # Press the 'd' key to jump forward a specified number of frames
    elif cv2.waitKey(1) & 0xFF == ord('d'):
        for _ in range(frame_skip):  # Skip the specified number of frames
            cap.grab()  # Grab the next frame without decoding it

# Release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 63.0ms
# Speed: 0.0ms preprocess, 63.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 25.6ms
# Speed: 0.0ms preprocess, 25.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 28.8ms
# Speed: 0.0ms preprocess, 28.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 31.9ms
# Speed: 0.0ms preprocess, 31.9ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 21.6ms
# Speed: 4.0ms preprocess, 21.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 red_yellow_flag, 1 blue_flag, 1 flagpole, 32.1ms
# Speed: 0.0ms preprocess, 32.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...
