# %%
# A_Aug_ ... Add file name
import os
import cv2
import numpy as np

def create_merged_filename(file_name, merge_from_job, source_class_id, merge_to_job, target_class, extension):
    """
    Create a new filename for the merged image or annotation based on user specifications.
    """
    base_name, _ = os.path.splitext(file_name)  # Retain the original file name
    new_name = (f"Merge_RY_{merge_from_job}_into_{merge_to_job}_class_{target_class}_{base_name}{extension}")
    return new_name

def check_files_exist(src_image_path, tgt_image_path, src_annotation_path, tgt_annotation_path):
    """
    Check if all required files exist and return True or False.
    """
    if not os.path.exists(src_image_path):
        print(f"Source image not found: {src_image_path}. Skipping.")
        return False
    if not os.path.exists(tgt_image_path):
        print(f"Target image not found: {tgt_image_path}. Skipping.")
        return False
    if not os.path.exists(src_annotation_path):
        print(f"Source annotation not found: {src_annotation_path}. Skipping.")
        return False
    if not os.path.exists(tgt_annotation_path):
        print(f"Target annotation not found: {tgt_annotation_path}. Skipping.")
        return False
    return True

def fill_bounding_box_with_background(tgt_image, annotation, target_class):
    """
    Fill the bounding box for the target class with a sampled background color.
    """
    image_height, image_width = tgt_image.shape[:2]
    target_bbox = None

    for class_id, x_center, y_center, width, height in annotation:
        if int(class_id) == target_class:
            x_min = int((x_center - width / 2) * image_width)
            y_min = int((y_center - height / 2) * image_height)
            x_max = int((x_center + width / 2) * image_width)
            y_max = int((y_center + height / 2) * image_height)

            # Sample background color from the top row of the bounding box
            top_row = tgt_image[y_min, x_min:x_max]
            background_color = top_row.mean(axis=0).astype(np.uint8)

            # Fill the bounding box with the sampled background color
            tgt_image[y_min:y_max, x_min:x_max] = background_color
            target_bbox = (x_min, y_min, x_max, y_max)
            break

    if target_bbox is None:
        print("No bounding box found for target class. Skipping background filling.")
    return tgt_image, target_bbox

def overlay_mask_on_bbox(src_mask, tgt_image, bbox_coords, scale_factor=1.0, x_offset=0):
    """
    Overlay the source mask on the bounding box area with a horizontal offset and scale factor.
    """
    x_min, y_min, x_max, y_max = bbox_coords

    # Resize mask to match bounding box dimensions with scale factor
    tgt_width = int((x_max - x_min) * scale_factor)
    tgt_height = int((y_max - y_min) * scale_factor)
    resized_mask = cv2.resize(src_mask, (tgt_width, tgt_height), interpolation=cv2.INTER_LINEAR)

    # Apply the x-offset
    x_min_offset = max(0, x_min + x_offset)
    x_max_offset = min(tgt_image.shape[1], x_min_offset + tgt_width)

    # Place the resized mask in the target image
    for c in range(3):
        tgt_image[y_min:y_min+tgt_height, x_min_offset:x_max_offset, c] = \
            resized_mask[:, :, c] * (resized_mask[:, :, 3] > 0) + \
            tgt_image[y_min:y_min+tgt_height, x_min_offset:x_max_offset, c] * (resized_mask[:, :, 3] == 0)

    return tgt_image, (x_min_offset, y_min, x_min_offset + tgt_width, y_min + tgt_height)

def process_images_with_mask_overlay(src_folder, tgt_folder, merge_folder, target_class, class_to_take, scale_factor=1.0, x_offset=0):
    """
    Process images and overlay masks with annotations and horizontal offset.
    """
    if not os.path.exists(merge_folder):
        os.makedirs(merge_folder)

    for file_name in os.listdir(src_folder):
        if not file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
            continue

        src_image_path = os.path.join(src_folder, file_name)
        tgt_image_path = os.path.join(tgt_folder, file_name)
        src_annotation_path = os.path.join(src_folder, os.path.splitext(file_name)[0] + ".txt")
        tgt_annotation_path = os.path.join(tgt_folder, os.path.splitext(file_name)[0] + ".txt")

        # Check file existence
        if not check_files_exist(src_image_path, tgt_image_path, src_annotation_path, tgt_annotation_path):
            continue

        # Load images and annotations
        src_image = cv2.imread(src_image_path)
        tgt_image = cv2.imread(tgt_image_path)
        with open(src_annotation_path, 'r') as f:
            src_annotations = [list(map(float, line.split())) for line in f]
        with open(tgt_annotation_path, 'r') as f:
            tgt_annotations = [list(map(float, line.split())) for line in f]

        # Create mask from the source image within the bounding box of the source class
        mask_path = os.path.join(merge_folder, f"mask_{file_name}")
        src_mask, _ = create_mask_within_bbox(src_image, src_annotations, class_to_take, mask_path)

        # Fill the bounding box for the target class with background color
        tgt_image, bbox_coords = fill_bounding_box_with_background(tgt_image, tgt_annotations, target_class)
        if bbox_coords is None:
            print(f"No bounding box for target class in {file_name}. Skipping.")
            continue

        # Overlay mask onto target image
        updated_image, new_bbox = overlay_mask_on_bbox(src_mask, tgt_image, bbox_coords, scale_factor, x_offset)

        # Update annotations
        updated_annotation = update_annotations_with_mask(new_bbox, tgt_image.shape, class_to_take)

        # Save output image and annotations
        new_image_filename = create_merged_filename(file_name, '30', class_to_take, '24', target_class, '.png')
        new_annotation_filename = create_merged_filename(file_name, '30', class_to_take, '24', target_class, '.txt')

        output_image_path = os.path.join(merge_folder, new_image_filename)
        output_annotation_path = os.path.join(merge_folder, new_annotation_filename)

        cv2.imwrite(output_image_path, updated_image)
        save_updated_annotations(tgt_annotations, updated_annotation, target_class, output_annotation_path)
        print(f"Processed: {output_image_path}, Annotation: {output_annotation_path}")

# ------------------------ Parameters ------------------------
src_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_out_of_30"
tgt_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_into_24_Filter"
merge_folder = "D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24"
class_to_take = 1  # Source class ID
target_class = 0   # Target class ID
scale_factor = 1.1  # Scale factor for resizing mask_RY_
x_offset = -15      # Horizontal offset for the overlay

process_images_with_mask_overlay(src_folder, tgt_folder, merge_folder, target_class, class_to_take, scale_factor, x_offset)

# ------------------------ Parameters ------------------------
#src_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_out_of_30"
#tgt_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_into_24_Filter"
#merge_folder = "D:/FlagDetectionDatasets/Augmentation/Merged_30_to_24"
#class_to_take = 1  # Source class ID
#target_class = 0   # Target class ID
#scale_factor = 1.2  # Scale factor for resizing mask

#process_images_with_mask_overlay(src_folder, tgt_folder, merge_folder, target_class, class_to_take, scale_factor)

# ------------------------- Parameters -------------------------
#src_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_out_of_30"
#tgt_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_into_24_F2"
#merge_folder = "D:/FlagDetectionDatasets/Augmentation/Merged_RY7_30_to_24"
#class_to_take = 1  # Source class
#target_class = 0   # Target class
#scale_factor = 1.2  # Scale factor for mask

process_images_with_mask_overlay(src_folder, tgt_folder, merge_folder, target_class, class_to_take, scale_factor)

# ------------------------- Parameters -------------------------
#src_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_out_of_30"
#tgt_folder = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_into_24_Filter"
#merge_folder = "D:/FlagDetectionDatasets/Augmentation/MergedRY4_30_to_24"
#class_to_take = 1  # Source class
#target_class = 0   # Target class
#scale_factor = 1.2  # my defined scale factor

# Paths and parameters
#merge_class_from = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_out_of_30"
#merge_class_into = "D:/FlagDetectionDatasets/Augmentation/Switch_flag_into_24_Filter"
#merge_fldr = "D:/FlagDetectionDatasets/Augmentation/Merged_RY2_30_to_24"
##class_to_take = 1  # Source class (red/yellow flag)
#class_to_replace = 0  # Target class (red flag)
#merge_from_job = '30'
#merge_to_job = '24'
# Out:
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000173.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000173.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000173.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000173.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000174.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000174.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000174.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000174.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000175.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000175.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000175.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000175.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000176.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000176.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000176.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000176.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000177.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000177.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000177.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000177.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000178.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000178.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000178.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000178.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000179.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000179.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000179.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000179.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000180.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000180.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000180.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000180.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000181.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000181.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000181.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000181.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000182.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000182.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000182.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000182.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000183.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000183.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000183.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000183.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000184.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000184.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000184.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000184.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000185.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000185.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000185.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000185.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000186.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000186.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000186.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000186.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000187.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000187.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000187.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000187.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000188.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000188.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000188.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000188.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000189.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000189.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000189.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000189.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000190.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000190.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000190.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000190.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000191.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000191.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000191.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000191.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000192.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000192.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000192.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000192.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000193.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000193.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000193.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000193.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000194.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000194.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000194.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000194.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000195.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000195.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000195.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000195.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000196.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000196.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000196.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000196.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000197.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000197.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000197.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000197.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000198.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000198.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000198.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000198.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000199.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000199.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000199.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000199.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000200.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000200.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000200.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000200.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000201.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000201.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000201.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000201.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000202.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000202.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000202.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000202.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000203.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000203.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000203.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000203.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000204.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000204.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000204.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000204.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000205.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000205.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000205.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000205.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000206.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000206.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000206.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000206.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000207.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000207.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000207.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000207.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000208.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000208.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000208.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000208.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000209.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000209.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000209.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000209.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000210.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000210.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000210.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000210.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000211.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000211.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000211.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000211.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000212.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000212.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000212.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000212.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000213.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000213.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000213.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000213.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000214.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000214.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000214.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000214.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000215.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000215.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000215.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000215.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000216.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000216.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000216.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000216.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000217.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000217.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000217.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000217.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000218.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000218.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000218.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000218.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000219.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000219.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000219.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000219.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000220.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000221.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000222.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000223.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000224.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000225.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000226.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000227.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000228.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000229.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000230.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000231.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000232.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000233.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000234.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000235.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000236.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000237.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000238.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000239.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000240.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000241.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000242.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000243.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000244.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000245.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000246.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000247.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000248.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000249.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000250.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000251.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000252.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000253.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000254.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000255.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000256.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000257.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000257.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000257.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000257.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000258.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000258.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000258.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000258.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000259.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000259.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000259.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000259.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000260.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000260.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000260.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000260.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000261.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000261.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000261.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000261.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000262.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000262.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000262.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000262.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000263.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000263.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000263.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000263.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000264.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000264.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000264.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000264.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000265.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000265.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000265.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000265.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000266.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000266.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000266.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000266.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000267.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000267.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000267.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000267.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000268.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000268.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000268.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000268.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000269.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000269.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000269.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000269.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000270.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000270.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000270.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000270.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000271.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000271.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000271.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000271.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000272.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000272.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000272.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000272.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000273.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000273.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000273.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000273.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000274.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000274.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000274.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000274.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000275.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000275.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000275.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000275.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000276.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000276.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000276.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000276.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000277.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000277.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000277.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000277.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000278.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000278.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000278.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000278.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000279.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000279.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000279.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000279.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000280.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000280.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000280.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000280.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000281.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000281.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000281.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000281.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000282.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000282.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000282.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000282.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000283.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000283.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000283.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000283.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000284.PNG
# ...
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000220.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000221.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000221.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000222.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000222.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000223.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000223.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000224.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000224.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000225.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000225.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000226.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000226.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000227.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000227.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000228.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000228.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000229.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000229.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000230.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000230.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000231.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000231.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000232.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000232.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000233.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000233.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000234.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000234.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000235.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000235.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000236.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000236.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000237.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000237.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000238.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000238.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000239.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000239.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000240.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000240.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000241.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000241.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000242.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000242.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000243.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000243.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000244.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000244.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000245.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000245.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000246.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000246.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000247.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000247.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000248.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000248.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000249.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000249.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000250.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000250.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000251.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000251.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000252.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000252.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000253.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000253.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000254.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000254.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000255.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000255.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000256.PNG
# Annotations saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.txt
# Processed: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.png, Annotation: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\Merge_RY_30_into_24_class_0_000256.txt
# Intermediate mask saved to: D:/FlagDetectionDatasets/Augmentation/MergeRY1_30_To_24\mask_000257.PNG
