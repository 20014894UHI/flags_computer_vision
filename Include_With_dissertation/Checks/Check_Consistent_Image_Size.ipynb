# %%
# Check for consistent image sizes 

import os
import cv2


def check_image_dimensions_and_sizes(parent_folder, required_width=1920, required_height=1080):
    """
    Check if all images in the parent folder and its subfolders are of the required dimensions,
    and calculate the total size of images per folder and overall.

    Args:
        parent_folder (str): Path to the folder containing images.
        required_width (int): The required width of the images.
        required_height (int): The required height of the images.
    """
    inconsistent_folders = []
    total_images_checked = 0
    total_size = 0  # Total size of all images (in bytes)

    print("Starting image dimension and size check...\n")

    for root, _, files in os.walk(parent_folder):
        print(f"Checking folder: {root}...")  
        has_inconsistent_images = False
        folder_image_count = 0
        folder_size = 0  # Total size of images in the current folder

        for file_name in files:
            if file_name.lower().endswith(('.png', '.jpg', '.jpeg')):
                file_path = os.path.join(root, file_name)
                folder_image_count += 1
                total_images_checked += 1

                # Get file size in bytes
                image_size = os.path.getsize(file_path)
                folder_size += image_size
                total_size += image_size

                # Read the image
                image = cv2.imread(file_path)
                if image is None:
                    print(f"Error reading image: {file_path}. Skipping.")
                    continue

                height, width = image.shape[:2]

                # Check dimensions
                if width != required_width or height != required_height:
                    print(f"Wrong dimensions: {file_path} ({width}x{height})")
                    has_inconsistent_images = True

        print(f"Folder size: {folder_size / (1024 * 1024):.2f} MB with {folder_image_count} images.\n")

        if folder_image_count == 0:
            print(f"No images found in folder: {root}")
        elif has_inconsistent_images:
            inconsistent_folders.append(root)

    # Report results
    if inconsistent_folders:
        print("\nSubfolders with wrong image dimensions:")
        for folder in inconsistent_folders:
            print(f" - {folder}")
    else:
        print("\nAll images match the required size.")

    print(f"\nTotal size of all images: {total_size / (1024 * 1024):.2f} MB")
    print(f"Dimension check complete. Total images checked: {total_images_checked}")

# Folder to check
#parent_folder = "D:/FlagDetectionDatasets/ExportedDatasetsSelectedML"
parent_folder = "D:/FlagDetectionDatasets/ExportedDatasetsReduced"

# Run the check
check_image_dimensions_and_sizes(parent_folder, required_width=1920, required_height=1080)
#check_image_dimensions_and_sizes(parent_folder, required_width=1920, required_height=1088)
# Out:
# Starting image dimension and size check...
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced...
# Folder size: 0.00 MB with 0 images.
#
# No images found in folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160...
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000125.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000225.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000050.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000175.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000025.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000275.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000200.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000075.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000150.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000250.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000000.PNG (1080x1920)
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_160\Job_160_000100.PNG (1080x1920)
# Folder size: 19.57 MB with 12 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_29...
# Folder size: 205.98 MB with 240 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_32...
# Folder size: 236.82 MB with 250 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_41...
# Folder size: 178.74 MB with 280 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_56...
# Folder size: 86.88 MB with 69 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_60...
# Folder size: 136.75 MB with 162 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_65...
# Folder size: 245.07 MB with 147 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_72...
# Folder size: 220.46 MB with 146 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_73...
# Folder size: 70.49 MB with 88 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_89...
# Folder size: 108.51 MB with 149 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_95...
# Folder size: 33.96 MB with 70 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_106...
# Folder size: 112.54 MB with 120 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_108...
# Folder size: 14.30 MB with 10 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_109...
# Folder size: 40.67 MB with 27 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_114...
# Folder size: 106.08 MB with 96 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_115...
# Folder size: 55.17 MB with 63 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_123...
# Folder size: 108.20 MB with 60 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_125...
# Folder size: 101.48 MB with 96 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_126...
# Folder size: 36.55 MB with 32 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_128...
# Folder size: 73.46 MB with 107 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_130...
# Folder size: 91.66 MB with 111 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_131...
# Folder size: 17.62 MB with 22 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_142...
# Folder size: 8.29 MB with 22 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_143...
# Folder size: 40.36 MB with 27 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_147...
# Folder size: 18.98 MB with 22 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_155...
# Folder size: 84.58 MB with 61 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_156...
# Folder size: 76.20 MB with 54 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_157...
# Folder size: 282.75 MB with 169 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_158...
# Folder size: 24.99 MB with 20 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_159...
# Inconsistent dimensions: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_159\OBO_000005.png (4608x2592)
# Folder size: 37.27 MB with 17 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_11...
# Folder size: 152.45 MB with 350 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_22...
# Folder size: 519.47 MB with 601 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_21...
# Folder size: 267.46 MB with 301 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_7...
# Folder size: 316.26 MB with 363 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_116...
# Folder size: 61.01 MB with 59 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_14...
# Folder size: 5.15 MB with 15 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_12...
# Folder size: 230.43 MB with 458 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_15...
# Folder size: 11.11 MB with 32 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_13...
# Folder size: 32.92 MB with 97 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_16...
# Folder size: 5.18 MB with 15 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_17...
# Folder size: 7.11 MB with 24 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_18...
# Folder size: 4.45 MB with 14 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_42...
# Folder size: 70.74 MB with 107 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_37...
# Folder size: 93.91 MB with 99 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_50...
# Folder size: 43.99 MB with 49 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_48...
# Folder size: 118.75 MB with 136 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_55...
# Folder size: 41.03 MB with 36 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_57...
# Folder size: 165.50 MB with 118 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_59...
# Folder size: 107.41 MB with 80 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_54...
# Folder size: 224.71 MB with 185 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_61...
# Folder size: 181.79 MB with 228 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_66...
# Folder size: 38.58 MB with 24 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_67...
# Folder size: 30.05 MB with 21 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_69...
# Folder size: 80.36 MB with 42 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_70...
# Folder size: 116.56 MB with 87 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_76...
# Folder size: 59.84 MB with 79 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_121...
# Folder size: 107.87 MB with 94 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_119...
# Folder size: 74.71 MB with 89 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_118...
# Folder size: 80.46 MB with 104 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_105...
# Folder size: 113.91 MB with 161 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_104...
# Folder size: 195.56 MB with 217 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_96...
# Folder size: 51.99 MB with 90 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_36...
# Folder size: 208.25 MB with 191 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_120...
# Folder size: 82.36 MB with 58 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_117...
# Folder size: 62.71 MB with 98 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_98...
# Folder size: 28.66 MB with 36 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_87...
# Folder size: 210.31 MB with 210 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_78...
# Folder size: 125.66 MB with 159 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_77...
# Folder size: 60.37 MB with 80 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_75...
# Folder size: 56.52 MB with 58 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_74...
# Folder size: 54.49 MB with 58 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_71...
# Folder size: 2431.33 MB with 1656 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_23...
# Folder size: 186.11 MB with 220 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_23_filter...
# Folder size: 221.53 MB with 255 images.
#
# Checking folder: D:/FlagDetectionDatasets/ExportedDatasetsReduced\Job_24_filter...
