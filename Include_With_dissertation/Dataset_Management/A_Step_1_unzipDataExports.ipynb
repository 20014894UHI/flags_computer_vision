# %%
# Step_1_unzipDataExports.jpynb
# Step 1: Files were exported from CVAT in Yolo 1.1. format (supported Yolo format available in CVAT local)
# Unzip all zip files exported in a folder , keeping the same stem file name. 
# Unzip a single zip file 

import os
import zipfile

def unzip_files(data_to_unzip, unzipped_data):
                
    # Ensure the output folder exists
    os.makedirs(unzipped_data, exist_ok=True)

    # Iterate over all files in the input folder
    for file_name in os.listdir(data_to_unzip):
        # Check if the file is a zip file
        if file_name.endswith('.zip'):
            # Construct the full path to the zip file
            zip_path = os.path.join(data_to_unzip, file_name)
            print(f"Starting to unzip {zip_path}...")
            # Create a folder named after the zip file 
            extract_folder_name = os.path.splitext(file_name)[0]
            extract_folder = os.path.join(unzipped_data, os.path.splitext(file_name)[0])
            os.makedirs(extract_folder, exist_ok=True)
            try:
                # Unzip the file into the new folder
                with zipfile.ZipFile(zip_path, 'r') as zip_ref:
                    zip_ref.extractall(extract_folder)
                print(f" - Unzipped {file_name} into {extract_folder}")
                # Check if files were extracted
                extracted_files = os.listdir(extract_folder)
                # if not extracted_files:
                #    print(f"Warning: No files extracted for {file_name}.")
                #else:
                #    print(f"Extracted files: {extracted_files}")     
            except zipfile.BadZipFile:
                print(f"Error: {file_name} is not a valid zip file.")
            except Exception as e:
                print(f"An error occurred while unzipping {file_name}: {e}")
                
### UNZIP A SPECIFIC ZIP 
def unzip_specific_zip(zip_file, data_to_unzip, unzipped_data):          
    """
    Unzip a specific zip file into a designated folder.
    :param zip_file: Name of the zip file to unzip.
    :param data_to_unzip: Path to the folder containing the zip file.
    :param unzipped_data: Path to the folder where the extracted files will be stored.
    """
    os.makedirs(unzipped_data, exist_ok=True)
    if not zip_file.endswith('.zip'):
        print(f"Error: {zip_file} is not a valid .zip file.")
        return
    zip_path = os.path.join(data_to_unzip, zip_file)
    extract_folder = os.path.join(unzipped_data, os.path.splitext(zip_file)[0])
    os.makedirs(extract_folder, exist_ok=True)
    try:
        print(f"Starting to unzip {zip_file}...")
        with zipfile.ZipFile(zip_path, 'r') as zip_ref:
            zip_ref.extractall(extract_folder)
        print(f" - Unzipped {zip_file} into {extract_folder}")
    except zipfile.BadZipFile:
        print(f"Error: {zip_file} is not a valid zip file.")
    except FileNotFoundError:
        print(f"Error: {zip_file} not found in {data_to_unzip}.")
    except Exception as e:
        print(f"An error occurred while unzipping {zip_file}: {e}")
            
#Unzip the ZIP files to the backup repository 
path_to_data_to_unzip = 'D:\FlagDetectionDatasets\ExportedTaskDatasetsZips\TODO' 
#path_to_unzipped_data = 'D:\FlagDetectionDatasets\ExportedDatasetsExtracted'
#unzip_files(path_to_data_to_unzip, path_to_unzipped_data)
# unzip to the current working directory  
#unzip_files(path_to_data_to_unzip, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')

path_to_data_single = 'D:\FlagDetectionDatasets\ExportedTaskDatasetsZips' 
#unzip_specific_zip("Job_13.zip", path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsExtracted')
#unzip_specific_zip('Job_24.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_67.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#Step 1
#unzip_specific_zip('Job_65.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_28.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_29.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_30.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_117.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')
#unzip_specific_zip('Job_118.zip', path_to_data_single, 'D:\FlagDetectionDatasets\ExportedDatasetsReduced')

# Unzip the files to a copy for trimming down for testing 
#path_to_data_to_unzip = 'D:\FlagDetectionDatasets\ExportedTaskDatasetsZips' 
#path_to_unzipped_data = 'D:\FlagDetectionDatasets\ExportedDatasetsNotSplitForTestSet'
#unzip_files(path_to_data_to_unzip, path_to_unzipped_data)
# Out:
# Starting to unzip Job_117.zip...
#  - Unzipped Job_117.zip into D:\FlagDetectionDatasets\ExportedDatasetsReduced\Job_117
# Starting to unzip Job_118.zip...
#  - Unzipped Job_118.zip into D:\FlagDetectionDatasets\ExportedDatasetsReduced\Job_118
