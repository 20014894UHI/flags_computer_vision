# %%
# Visualisation of augmentation and reduction cycle for Job_54 
from graphviz import Digraph

# Create a new directed graph
dot = Digraph(format='png', engine='dot')
#dot = Digraph(format='pdf', engine='dot')

# Set global attributes 
dot.attr(dpi='300', rankdir='TB', fontname='Helvetica')  # Roboto alternative Helvetica
dot.attr('node', fontsize='20')  # Default font size for nodes
dot.attr('edge', fontsize='20')  # Default font size for edges

dot.node('A', '(a) Extracted set [Approx 100k images]', shape='box', style='filled', fillcolor='lightblue', fontsize='18')

# Exampke with thumbnail 
#dot.node( 'F',  label='Label', shape='box', style='filled', fillcolor='orange', image='thumbnails/augmented.png',  Path to thumbnaillabelloc='D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_THUMB1.png')
#dot.node('F', label='Label', shape='box', style='filled', fillcolor='orange',image='D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_THUMB1.png',  labelloc='b')
#dot.node('A', label=r'< <TABLE BORDER="0" CELLBORDER="0" CELLPADDING="4"><TR><TD><IMG SRC="image.png" SCALE="TRUE" WIDTH="50" HEIGHT="50"/></TD><TD>Label beside image</TD></TR></TABLE> >', shape='plaintext')

#dot.node('C', 'Job_54 set in "Reduced" set [780 images 942MB]', shape='box', style='filled', fillcolor='lightyellow', image='D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_THUMB1.png',  labelloc='c')
dot.node('C', 
         label=r'< <TABLE BORDER="0" CELLBORDER="0" CELLPADDING="4"><TR><TD><IMG SRC="D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_THUMB1.png" SCALE="TRUE" WIDTH="50" HEIGHT="50"/></TD><TD>(b) Job_54 set in "Reduced" set [780 images 942MB]</TD></TR></TABLE> >', 
         shape='box', 
         style='filled', 
         fillcolor='lightyellow',
         fontsize='18')
dot.edge('A', 'C', label='1. Copy "Extracted" set to create "Reduced" set',  fontcolor='black',  fontsize='18')

dot.node('C_ssim', '(c) Job_54 Reduced by SSIM [185 images 224MB] \n', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C', 'C_ssim', label=" 2. Reduce by SSIM", fontcolor='black',  fontsize='18')

dot.node('C_ref', '(d) Job_54 Saved to "Reference" set [185 images 224MB] \n', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_ssim', 'C_ref', label=" 3. Save to Reference set", fontcolor='black')

dot.node('C_sel', '(e) Job_54 Copied to "Selected" set [185 images 224MB] \n', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_ref', 'C_sel', label=" 4. Copy to Selected set", fontcolor='black',  fontsize='18')

dot.node('C_pat', '(f) Job_54 Reduced by pattern', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_sel', 'C_pat', label=" 5. Reduce by pattern ", fontcolor='black',  fontsize='18')

# Job_54
dot.node('C_pat2', '(g) Job_54 Repeated reduced by pattern [84 images]', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_pat', 'C_pat2', label=" 6. Reduce by pattern (repeat)", fontcolor='black')

# Job_54_illum # Job_54_000000_illumtHUMB.png
#dot.node('C_patIll', 'Job_54 Illum \n Optimised Illumination [84 images]', shape='box', style='filled', fillcolor='lightpink')
dot.node('C_patIll', 
         #'Job_54 Illum \n Optimised Illumination [84 images]', 
         label=r'< <TABLE BORDER="0" CELLBORDER="0" CELLPADDING="4"><TR><TD><IMG SRC="D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_illumtHUMB.png" SCALE="TRUE" WIDTH="50" HEIGHT="50"/></TD><TD>(i) Job_54 Illum \n Optimised Illumination [84 images], </TD></TR></TABLE> >', 
         shape='box', 
         style='filled', 
         fillcolor='lightpink',  
         fontsize='18')
dot.edge('C_pat2', 'C_patIll', label=" 10. Change illumination properties",  fontcolor='black',  fontsize='18')

# Job_54_illum spliced
dot.node('C_patIllspl', '(k) Job_54 \n  Optimised Illumination Spliced [42 images]', shape='box', style='filled', fillcolor='lightpink',  fontsize='18')
dot.edge('C_patIll', 'C_patIllspl', label=" 11. Splice - delete alternative images",  fontcolor='black',  fontsize='18')

#Job_54_000000_scaled_THUMB1.png
#dot.node('C_scl', 'Job_54_Aug: Scaled x 2.5 [84 images]', shape='box', style='filled', fillcolor='orange')
dot.node('C_scl', 
         label=r'< <TABLE BORDER="0" CELLBORDER="0" CELLPADDING="4"><TR><TD><IMG SRC="D:/Flagdetectiondatasets/a_pSDS/Job_54_000000_scaled_THUMB1.png" SCALE="TRUE" WIDTH="50" HEIGHT="50"/></TD><TD>(h) Job_54_Aug: Scaled x 2.5 [84 images]</TD></TR></TABLE> >', 
         shape='box', 
         style='filled', 
         fillcolor='orange',  
         fontsize='18')
dot.edge('C_pat2', 'C_scl', label=" 7. Augmentation: Scale factor applied",  fontcolor='black',  fontsize='18')

# Job_54_Aug_illum Job_54_000001_scaled_ILLUM_THUMB.png
#dot.node('C_patAugIll', 'Job_54 Aug Illum \n Scaled + Optimised Illumination [84 images]', shape='box', style='filled', fillcolor='lightpink')
dot.node('C_patAugIll', 
         label=r'< <TABLE BORDER="0" CELLBORDER="0" CELLPADDING="4"><TR><TD><IMG SRC="D:/Flagdetectiondatasets/a_pSDS/Job_54_000001_scaled_ILLUM_THUMB.png" SCALE="TRUE" WIDTH="50" HEIGHT="50"/></TD><TD> (j) Job_54 Aug Illum \n Scaled + Optimised Illumination [84 images]</TD></TR></TABLE> >', 
         shape='box', style='filled', 
         fillcolor='lightpink',  
         fontsize='18')
dot.edge('C_scl', 'C_patAugIll', label=" 10. Change illumination properties",  fontcolor='black',  fontsize='18')

# Job_54_Aug_illum spliced 
dot.node('C_patAugIllspl', '(l) Job_54 Aug Illum Spliced \n Scaleed + Optimised Illumination \n Spliced [42 images]', shape='box', style='filled', fillcolor='lightpink',  fontsize='18')
dot.edge('C_patAugIll', 'C_patAugIllspl', label=" 11. Splice - delete alternative images",  fontcolor='black',  fontsize='18')

dot.node('C_og_scl1', '(n) Job_54 Original Spliced [42 images]', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_pat2', 'C_og_scl1', label=" 8. Splice - delete alternate images",  fontcolor='black',  fontsize='18')
dot.node('C_og_scl2', '(m) Job_54 Scaled Spliced [42 images]', shape='box', style='filled', fillcolor='orange',  fontsize='18')
dot.edge('C_scl', 'C_og_scl2', label=" 8. Splice - delete alternate images",  fontcolor='black',  fontsize='18')

dot.node('C_og_scl3a', '(o) Job_54 Scaled [5 images]', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.node('C_og_scl3b', '(p) Job_54 Original [5 images]', shape='box', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_og_scl2', 'C_og_scl3a', label=" Final review \n Keep 1 in 8",  fontcolor='black',  fontsize='18')
dot.edge('C_og_scl1', 'C_og_scl3b', label=" Final review \n Keep 1 in 8",  fontcolor='black',  fontsize='18')
# circle to merge 
dot.node('C_og_scl3', ' ', shape='circle', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_og_scl3a', 'C_og_scl3', label=" Final review \n Keep 1 in 8",  fontcolor='black',  fontsize='18')
dot.edge('C_og_scl3b', 'C_og_scl3', label=" Final review \n Keep 1 in 8",  fontcolor='black',  fontsize='18')

# converge 
dot.node('C_og_scl4', '(q) Job_54 Original and Scaled Merged [10 images]', shape='box', style='filled', fillcolor='orange',  fontsize='18')
dot.edge('C_og_scl3', 'C_og_scl4', label=" 9. Merge",  fontcolor='black',  fontsize='18')

# circle to merge 
dot.node('C_patAugIllC_patIll_circle', ' ', shape='circle', style='filled', fillcolor='lightyellow',  fontsize='18')
dot.edge('C_patAugIllspl', 'C_patAugIllC_patIll_circle', label=" ",  fontcolor='black',  fontsize='18')
dot.edge('C_patIllspl', 'C_patAugIllC_patIll_circle', label=" ",  fontcolor='black',  fontsize='18')

dot.node('C_patAugIllC_patIll_box', '(r) (Optimised Illumination) + \n (Scaled + Optimised Illumination) \n Merged [84 images]', shape='box', style='filled', fillcolor='lightpink',  fontsize='18')
dot.edge('C_patAugIllC_patIll_circle', 'C_patAugIllC_patIll_box', label=" 12. Merge",  fontcolor='black',  fontsize='18')

# Ensure S23FilterMerged, S23Merged, and C__illumE are on the same rank (side by side)
with dot.subgraph() as s:
    s.attr(rank='same')
    s.node('C_patAugIll')
    s.node('C_patIll')

with dot.subgraph() as s:
    s.attr(rank='same')
    s.node('C_og_scl4') ## Q
    s.node('C_patAugIllC_patIll_box')  ## R

with dot.subgraph() as s:
    s.attr(rank='same')
    s.node('C_patAugIll')
    s.node('C_patIll')

with dot.subgraph() as s:
    s.attr(rank='same')
    s.node('C_patAugIllspl')
    s.node('C_patIllspl')
    s.node('C_og_scl1')
    s.node('C_og_scl2')

# Render the graph
output_file = dot.render('Sequence_Job54', view=True)
print(f"Flowchart saved as: {output_file}")
# Out:
# ...
# in label of node C
# ...
# in label of node C_patIll
# ...
# in label of node C_scl
# ...
# in label of node C_patAugIll
# Flowchart saved as: Sequence_Job54.png
