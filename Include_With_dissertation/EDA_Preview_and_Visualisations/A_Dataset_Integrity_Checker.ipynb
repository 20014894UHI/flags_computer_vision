# %%
# Check integrity of the data at important stages especially before kicking off the ML 
"""
Script Name: Dataset Integrity Checker
Description: This script checks a folder of subfolders for:
    - Missing image-annotation pairs
    - Presence of files with "frame" in their names
    - Summarizes the findings for each subfolder

Dependencies:
    - Python 3
    - Standard libraries: os

"""
#=====================================================================================================================================#

import os

def delete_orphan_images(whichfolder, folder):

    print(f"Startin pattern for {folder}")
    path = os.path.join(whichfolder, folder)
    if not os.path.exists(path):
        print(f"Error: The folder {path} does not exist.")
        return
    files = os.listdir(path)
    image_files = sorted([f for f in files if f.lower().endswith(('.png', '.jpg', '.jpeg'))])
    text_files = sorted([f for f in files if f.lower().endswith('.txt')])
    paired_files = []
    for image_file in image_files:
        base_name = os.path.splitext(image_file)[0]
        annotation_file = f"{base_name}.txt"
        if annotation_file in text_files:
            paired_files.append((image_file, annotation_file))
        else:
            print(f"identified orphan file {image_file}")
            os.remove(os.path.join(path, image_file))
    for text_file in text_files:
        base_name = os.path.splitext(text_file)[0]
        image_file = f"{base_name}.PNG"
        if image_file in image_files:
            paired_files.append((image_file, text_file))
            #print(f"Paired files {image_file}")
        else:
            print(f"identified orphan file {text_file}")
            os.remove(os.path.join(path, text_file))
            
print(f"Finito")

#============================================================================================================================================

def check_missing_files(folder_path):
    """
    Check for missing annotations and missing images in a folder.

    Args:
        folder_path (str): Path to the folder containing images and annotations.

    Returns:
        None. Prints missing files and a summary.
    """
    # Collect all image and annotation filenames
    images = [
        os.path.splitext(f)[0] for f in os.listdir(folder_path)
        if f.lower().endswith(('.png', '.jpg', '.jpeg'))
    ]
    annotations = [
        os.path.splitext(f)[0] for f in os.listdir(folder_path)
        if f.lower().endswith('.txt')
    ]

    # Find missing annotations and images
    missing_annotations = [img for img in images if img not in annotations]
    missing_images = [ann for ann in annotations if ann not in images]

    # Print results
    print("\n--- Missing Annotations ---")
    if missing_annotations:
        for img in missing_annotations:
            print(f" ---------------------------------Annotation missing for image: {img}")
    else:
       print("No missing annotations.")

    print("\n--- Missing Images ---")
    if missing_images:
        for ann in missing_images:
            print(f"-------------------------------- Image missing for annotation: {ann}")
    else:
        print("No missing images.")

    # Summary
    print("\n--- Summary ---")
    print(f"Total images: {len(images)}")
    print(f"Total annotations: {len(annotations)}")
    print(f"Missing annotations: {len(missing_annotations)}")
    print(f"Missing images: {len(missing_images)}")

#===================================================================================================================================================================#

def check_missing_files_in_folders(parent_folder):
    """
    Check for missing annotations, images, and files with "frame" in the name in a folder containing multiple subfolders.

    Args:
        parent_folder (str): Path to the parent folder containing subfolders.

    Returns:
        None. Prints missing files and a summary for each subfolder.
    """
    for subfolder in os.listdir(parent_folder):
        subfolder_path = os.path.join(parent_folder, subfolder)

        if not os.path.isdir(subfolder_path):
            continue  # Skip if not a folder

        print(f"\nChecking folder: {subfolder}")

        # Collect all image and annotation filenames
        images = [
            os.path.splitext(f)[0] for f in os.listdir(subfolder_path)
            if f.lower().endswith(('.png', '.jpg', '.jpeg'))
        ]
        annotations = [
            os.path.splitext(f)[0] for f in os.listdir(subfolder_path)
            if f.lower().endswith('.txt')
        ]

        # Find missing annotations and images
        missing_annotations = [img for img in images if img not in annotations]
        missing_images = [ann for ann in annotations if ann not in images]

        # Check for files with "frame" in the name
        frame_files = [f for f in os.listdir(subfolder_path) if "frame" in f.lower()]

        # Print results
        # print("------------------------------------------------------------ Missing Annotations ---")
        if missing_annotations:
            for img in missing_annotations:
                print(f"                                                   Annotation missing for image: {img}")
        #else:
        #    print("No missing annotations.")

        # print("---------------------------------------------------------    Missing Images ---")
        if missing_images:
            for ann in missing_images:
                print(f"Image missing for annotation: {ann}")
        #else:
        #    print("No missing images.")

        if frame_files:
            print("-------------------------------------------------         Alert: Files with 'frame' in the name ---")
            for frame_file in frame_files:
                print(f"File: {frame_file}")

        # Summary
        print("--- Summary ---")
        #print(f"Total images: {len(images)}")
        #print(f"Total annotations: {len(annotations)}")
        print(f"Missing annotations: {len(missing_annotations)}")
        print(f"Missing images: {len(missing_images)}")


base_path_tgt = 'D:/FlagDetectionDatasets/ExportedDatasetsSelectedML'

#delete_orphan_images(base_path_tgt, 'Job_76')
#check_missing_files(base_path_tgt)
check_missing_files_in_folders('D:/FlagDetectionDatasets/ExportedDatasetsSelectedML')
# Out:
# Finito
#
# Checking folder: Job_7
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_11
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_12
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_13
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_14
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_15
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_16
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_21
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_17
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_18
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_24
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_24_filter
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_25
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_27
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_28
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_29
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_30
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_31
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_32
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_36
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_37
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_41
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_43
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_48
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_50
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_55
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_56
#                                                    Annotation missing for image: Job_56_000008
# --- Summary ---
# Missing annotations: 1
# Missing images: 0
#
# Checking folder: Job_57
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_59
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_60
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_61
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_65
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_66
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_67
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_69
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_70
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_71
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_72
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_73
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_74
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_75
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_76
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_77
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_78
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_87
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_89
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_95
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_96
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_98
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_104
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_105
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_106
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_108
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_109
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_114
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_115
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_116
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_117
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_118
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_119
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_120
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_121
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_123
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_125
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_126
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_128
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_130
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_131
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_142
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_143
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_147
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_156
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_157
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_158
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_159
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_22
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_88
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_11_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_12_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_16_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_21_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_22_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_27_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_30_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_31_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_32_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_36_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_41_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_24_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_24_filter_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_42_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_48_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_50_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_55_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_59_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_60_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_61_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_70_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_74_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_75_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_76_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_87_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_88_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_89_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_95_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_104_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_105_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_106_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_108_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_118_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_117_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_116_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_119_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_123_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_125_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_126_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_130_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_143_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_14_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_29_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_43_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_56_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_57_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_42
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_65_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_7_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_37_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_37_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_54_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_54_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_55_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_55_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_56_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_56_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_57_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_57_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_60_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_60_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_61_Aug_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_61_ILLUM
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_43_RY_Swapped_to_88
# -------------------------------------------------         Alert: Files with 'frame' in the name ---
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000000.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000010.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000030.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000040.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000050.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000060.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000070.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000080.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000090.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000100.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000110.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000120.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000130.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000140.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000150.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000160.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000170.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000180.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000190.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000200.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000210.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000220.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000230.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000240.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000250.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000260.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000270.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000280.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000290.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000300.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000310.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000320.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000330.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000340.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000350.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000360.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000370.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000380.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000390.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000400.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000410.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000420.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000430.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000440.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000450.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000460.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000470.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000480.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000490.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000500.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000510.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000520.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000530.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000540.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000550.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000560.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000570.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000580.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000590.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000600.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000610.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000620.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000630.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000640.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000650.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000660.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000670.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000680.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000690.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000700.jpg
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000700.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000000.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000010.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000030.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000040.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000050.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000060.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000070.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000080.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000090.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000100.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000110.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000120.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000130.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000140.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000150.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000160.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000170.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000180.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000190.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000200.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000210.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000220.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000230.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000240.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000250.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000260.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000270.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000280.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000290.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000300.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000310.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000320.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000330.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000340.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000350.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000360.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000370.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000380.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000390.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000400.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000410.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000420.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000430.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000440.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000450.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000460.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000470.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000480.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000490.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000500.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000510.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000520.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000530.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000540.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000550.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000560.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000570.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000580.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000590.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000600.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000610.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000620.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000630.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000640.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000650.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000660.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000670.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000680.txt
# File: Merge_43_CLS_1_into_88_CLS_0_frame_000690.txt
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_161_Aug_Perpsective
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_121_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_37_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_23_flt_Job_23_flt_Aug_Mrg
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_54_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_54
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_51_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_52_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_23_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_23
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_115_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_114_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_77_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_78_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_7_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_13_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_15_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_17_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_18_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_73_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_25_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_145
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_145_Aug
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_146
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_160
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_151
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
#
# Checking folder: Job_155
# --- Summary ---
# Missing annotations: 0
# Missing images: 0
