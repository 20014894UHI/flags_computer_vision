# %%
# Early days testing 
# Resize the images and keep the aspect ratio 
# Recursive Folder Search (os.walk):
# It processes each image file it finds.
# Resize and Overwrite:
# Calculates the appropriate height to maintain the aspect ratio and resizes it using cv2.resize().
# OverwritE original with the resized version using cv2.imwrite().

import cv2
import os
import time # Next 3 are For time and platform 
import platform
import psutil


def resize_images(input_folder, output_folder, target_size=(416, 416)):
    # Create output folder if it doesn't exist
    os.makedirs(output_folder, exist_ok=True)

    # Iterate through all images in the input folder
    for filename in os.listdir(input_folder):
        if filename.endswith(('.png','.PNG', '.jpg', '.jpeg')):
            # Read the image
            img_path = os.path.join(input_folder, filename)
            image = cv2.imread(img_path)
            resized_image = cv2.resize(image, target_size)
            cv2.imwrite(os.path.join(output_folder, filename), resized_image)
    
def resize_images_in_folder(folder_path, target_width=1280):
    start_time = time.time()  # Start timer
    processor = platform.processor()  # Get processor info
   
    # Walk through the folder and its subfolders
    for root, _, files in os.walk(folder_path):
        for file_name in files:
            # Check if the file is an image (you can add more extensions if needed)
            if file_name.lower().endswith(('.png', '.PNG', '.jpg', '.jpeg')):
                image_path = os.path.join(root, file_name)
                resize_image(image_path, target_width)
                print(f"Resized {image_path}")

    end_time = time.time()  # End timer
    elapsed_time = end_time - start_time  # Calculate elapsed time
    print(f"\nResizing complete.")
    #print(f"Time taken: {elapsed_time:.2f} seconds")
    print(f"Processor used: {processor}")

def resize_image(image_path, target_width):
    # Read the image using OpenCV
    image = cv2.imread(image_path)
    
    # Check if the image was successfully loaded
    if image is None:
        print(f"Error reading {image_path}")
        return
    
    # Get original dimensions
    original_height, original_width = image.shape[:2]
    
    # Calculate the new height to maintain aspect ratio
    aspect_ratio = original_height / original_width
    new_height = int(target_width * aspect_ratio)
    
    # Resize the image
    resized_image = cv2.resize(image, (target_width, new_height))
    
    # Overwrite the original image
    cv2.imwrite(image_path, resized_image)


# check GPU version 
#print(cv2.getBuildInformation())
#device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Path to folder of extracted frames
input_folder = r'D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy'
output_folder = r'D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\testout'

resize_images_in_folder(input_folder)
# Out:
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002770.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001690.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001545.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002310.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001865.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000755.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001220.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000805.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003390.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002610.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000325.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000510.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003240.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001850.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003515.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001445.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001480.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001045.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001585.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000715.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001890.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000045.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002125.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003215.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003455.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002730.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003290.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001770.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000420.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000750.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002715.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000195.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000620.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000410.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003330.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001895.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001940.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002775.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003520.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002720.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000975.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002850.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003210.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003065.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000240.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001820.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000935.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001580.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002065.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002385.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003275.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000245.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003305.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001255.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000615.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002275.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002515.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001320.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000875.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001650.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001960.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002045.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002825.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002335.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002230.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000850.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000485.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001870.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_003585.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000055.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000920.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_001110.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_000640.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_002905.PNG
# Resized D:\FlagDetectionDatasets\ExportedDatasetsExtracted\Job_7\obj_train_dataCopy\frame_